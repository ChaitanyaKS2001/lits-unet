# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import glob

import nibabel as nib
import cv2
import imageio
from tqdm.notebook import tqdm
from ipywidgets import *
from PIL import Image

# %%
from fastai.basics import *
from fastai.vision.all import *
from fastai.data.transforms import *
# Out:
# c:\Users\surya\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: [WinError 127] The specified procedure could not be found
#   warn(f"Failed to load image Python extension: {e}")

# %%
for dirname, _, filenames in os.walk('ct_scans'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ct_scans\segmentation\segmentation-0.nii
# ct_scans\segmentation\segmentation-1.nii
# ct_scans\segmentation\segmentation-10.nii
# ct_scans\segmentation\segmentation-11.nii
# ct_scans\segmentation\segmentation-12.nii
# ct_scans\segmentation\segmentation-13.nii
# ct_scans\segmentation\segmentation-14.nii
# ct_scans\segmentation\segmentation-15.nii
# ct_scans\segmentation\segmentation-16.nii
# ct_scans\segmentation\segmentation-17.nii
# ct_scans\segmentation\segmentation-18.nii
# ct_scans\segmentation\segmentation-19.nii
# ct_scans\segmentation\segmentation-2.nii
# ct_scans\segmentation\segmentation-20.nii
# ct_scans\segmentation\segmentation-21.nii
# ct_scans\segmentation\segmentation-22.nii
# ct_scans\segmentation\segmentation-23.nii
# ct_scans\segmentation\segmentation-24.nii
# ct_scans\segmentation\segmentation-25.nii
# ct_scans\segmentation\segmentation-26.nii
# ct_scans\segmentation\segmentation-27.nii
# ct_scans\segmentation\segmentation-28.nii
# ct_scans\segmentation\segmentation-29.nii
# ct_scans\segmentation\segmentation-3.nii
# ct_scans\segmentation\segmentation-30.nii
# ct_scans\segmentation\segmentation-4.nii
# ct_scans\segmentation\segmentation-5.nii
# ct_scans\segmentation\segmentation-6.nii
# ct_scans\segmentation\segmentation-7.nii
# ct_scans\segmentation\segmentation-8.nii
# ct_scans\segmentation\segmentation-9.nii
# ct_scans\volume\volume-0.nii
# ct_scans\volume\volume-1.nii
# ct_scans\volume\volume-10.nii
# ct_scans\volume\volume-11.nii
# ct_scans\volume\volume-12.nii
# ct_scans\volume\volume-13.nii
# ct_scans\volume\volume-14.nii
# ct_scans\volume\volume-15.nii
# ct_scans\volume\volume-16.nii
# ct_scans\volume\volume-17.nii
# ct_scans\volume\volume-18.nii
# ct_scans\volume\volume-19.nii
# ct_scans\volume\volume-2.nii
# ct_scans\volume\volume-20.nii
# ct_scans\volume\volume-21.nii
# ct_scans\volume\volume-22.nii
# ct_scans\volume\volume-23.nii
# ct_scans\volume\volume-24.nii
# ct_scans\volume\volume-25.nii
# ct_scans\volume\volume-26.nii
# ct_scans\volume\volume-27.nii
# ct_scans\volume\volume-28.nii
# ct_scans\volume\volume-29.nii
# ct_scans\volume\volume-3.nii
# ct_scans\volume\volume-30.nii
# ct_scans\volume\volume-4.nii
# ct_scans\volume\volume-5.nii
# ct_scans\volume\volume-6.nii
# ct_scans\volume\volume-7.nii
# ct_scans\volume\volume-8.nii
# ct_scans\volume\volume-9.nii

# %%
# Create a meta file for nii files processing

file_list = []
for dirname, _, filenames in os.walk('ct_scans'):
    for filename in filenames:
#         print(os.path.join(dirname, filename))
        file_list.append((dirname,filename)) 

df_files = pd.DataFrame(file_list, columns =['dirname', 'filename']) 
df_files.sort_values(by=['filename'], ascending=True)
# Out:
#                   dirname             filename
# 0   ct_scans\segmentation   segmentation-0.nii
# 1   ct_scans\segmentation   segmentation-1.nii
# 2   ct_scans\segmentation  segmentation-10.nii
# 3   ct_scans\segmentation  segmentation-11.nii
# 4   ct_scans\segmentation  segmentation-12.nii
# ..                    ...                  ...
# 57        ct_scans\volume         volume-5.nii
# 58        ct_scans\volume         volume-6.nii
# 59        ct_scans\volume         volume-7.nii
# 60        ct_scans\volume         volume-8.nii
# 61        ct_scans\volume         volume-9.nii
#
# [62 rows x 2 columns]

# %%
# Map CT scan and label 

df_files["mask_dirname"] = "" ; df_files["mask_filename"] = ""

for i in range(31):
    ct = f"volume-{i}.nii"
    mask = f"segmentation-{i}.nii"
    
    df_files.loc[df_files['filename'] == ct, 'mask_filename'] = mask
    df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = "ct_scans/segmentation"

# drop segment rows
df_files = df_files[df_files.mask_filename != ''].sort_values(by=['filename']).reset_index(drop=True) 
print(len(df_files))
df_files
# Out:
# 31
#             dirname       filename           mask_dirname        mask_filename
# 0   ct_scans\volume   volume-0.nii  ct_scans/segmentation   segmentation-0.nii
# 1   ct_scans\volume   volume-1.nii  ct_scans/segmentation   segmentation-1.nii
# 2   ct_scans\volume  volume-10.nii  ct_scans/segmentation  segmentation-10.nii
# 3   ct_scans\volume  volume-11.nii  ct_scans/segmentation  segmentation-11.nii
# 4   ct_scans\volume  volume-12.nii  ct_scans/segmentation  segmentation-12.nii
# 5   ct_scans\volume  volume-13.nii  ct_scans/segmentation  segmentation-13.nii
# 6   ct_scans\volume  volume-14.nii  ct_scans/segmentation  segmentation-14.nii
# 7   ct_scans\volume  volume-15.nii  ct_scans/segmentation  segmentation-15.nii
# 8   ct_scans\volume  volume-16.nii  ct_scans/segmentation  segmentation-16.nii
# 9   ct_scans\volume  volume-17.nii  ct_scans/segmentation  segmentation-17.nii
# 10  ct_scans\volume  volume-18.nii  ct_scans/segmentation  segmentation-18.nii
# 11  ct_scans\volume  volume-19.nii  ct_scans/segmentation  segmentation-19.nii
# 12  ct_scans\volume   volume-2.nii  ct_scans/segmentation   segmentation-2.nii
# 13  ct_scans\volume  volume-20.nii  ct_scans/segmentation  segmentation-20.nii
# 14  ct_scans\volume  volume-21.nii  ct_scans/segmentation  segmentation-21.nii
# 15  ct_scans\volume  volume-22.nii  ct_scans/segmentation  segmentation-22.nii
# 16  ct_scans\volume  volume-23.nii  ct_scans/segmentation  segmentation-23.nii
# 17  ct_scans\volume  volume-24.nii  ct_scans/segmentation  segmentation-24.nii
# 18  ct_scans\volume  volume-25.nii  ct_scans/segmentation  segmentation-25.nii
# 19  ct_scans\volume  volume-26.nii  ct_scans/segmentation  segmentation-26.nii
# 20  ct_scans\volume  volume-27.nii  ct_scans/segmentation  segmentation-27.nii
# 21  ct_scans\volume  volume-28.nii  ct_scans/segmentation  segmentation-28.nii
# 22  ct_scans\volume  volume-29.nii  ct_scans/segmentation  segmentation-29.nii
# 23  ct_scans\volume   volume-3.nii  ct_scans/segmentation   segmentation-3.nii
# 24  ct_scans\volume  volume-30.nii  ct_scans/segmentation  segmentation-30.nii
# 25  ct_scans\volume   volume-4.nii  ct_scans/segmentation   segmentation-4.nii
# 26  ct_scans\volume   volume-5.nii  ct_scans/segmentation   segmentation-5.nii
# 27  ct_scans\volume   volume-6.nii  ct_scans/segmentation   segmentation-6.nii
# 28  ct_scans\volume   volume-7.nii  ct_scans/segmentation   segmentation-7.nii
# 29  ct_scans\volume   volume-8.nii  ct_scans/segmentation   segmentation-8.nii
# 30  ct_scans\volume   volume-9.nii  ct_scans/segmentation   segmentation-9.nii

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample = 0
sample_ct   = read_nii(df_files.loc[sample,'dirname']+"/"+df_files.loc[sample,'filename'])
sample_mask  = read_nii(df_files.loc[sample,'mask_dirname']+"/"+df_files.loc[sample,'mask_filename'])
sample_ct.shape, sample_mask.shape
# Out:
# ((512, 512, 75), (512, 512, 75))

# %%
print(np.amin(sample_ct), np.amax(sample_ct))
print(np.amin(sample_mask), np.amax(sample_mask))
# Out:
# -3024.0 1410.0
# 0.0 2.0

# %%
# Preprocess the nii file 

dicom_windows = types.SimpleNamespace(
    brain=(80,40),
    subdural=(254,100),
    stroke=(8,32),
    brain_bone=(2800,600),
    brain_soft=(375,40),
    lungs=(1500,-600),
    mediastinum=(350,50),
    abdomen_soft=(400,50),
    liver=(150,30),
    spine_soft=(250,50),
    spine_bone=(1800,400),
    custom = (200,60)
)

@patch
def windowed(self:Tensor, w, l):
    px = self.clone()
    px_min = l - w//2
    px_max = l + w//2
    px[px<px_min] = px_min
    px[px>px_max] = px_max
    return (px-px_min) / (px_max-px_min)

plt.imshow(tensor(sample_ct[...,50].astype(np.float32)).windowed(*dicom_windows.liver), cmap=plt.cm.bone);

# %%
def plot_sample(array_list, color_map = 'nipy_spectral'):
    '''
    Plots and a slice with all available annotations
    '''
    fig = plt.figure(figsize=(18,15))

    plt.subplot(1,4,1)
    plt.imshow(array_list[0], cmap='bone')
    plt.title('Original Image')
    
    plt.subplot(1,4,2)
    plt.imshow(tensor(array_list[0].astype(np.float32)).windowed(*dicom_windows.liver), cmap='bone');
    plt.title('Windowed Image')
    
    plt.subplot(1,4,3)
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Mask')
    
    plt.subplot(1,4,4)
    plt.imshow(array_list[0], cmap='bone')
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Liver & Mask')


    plt.show()

# %%
sample=50
sample_slice = tensor(sample_ct[...,sample].astype(np.float32))

plot_sample([sample_ct[...,sample], sample_mask[...,sample]])

# %%
# Check the mask values
mask = Image.fromarray(sample_mask[...,sample].astype('uint8'), mode="L")
unique, counts = np.unique(mask, return_counts=True)
print( np.array((unique, counts)).T)
# Out:
# [[     0 252049]
#  [     1  10095]]

# %%
# Preprocessing functions

class TensorCTScan(TensorImageBW): _show_args = {'cmap':'bone'}

@patch
def freqhist_bins(self:Tensor, n_bins=100):
    "A function to split the range of pixel values into groups, such that each group has around the same number of pixels"
    imsd = self.view(-1).sort()[0]
    t = torch.cat([tensor([0.001]),
                   torch.arange(n_bins).float()/n_bins+(1/2/n_bins),
                   tensor([0.999])])
    t = (len(imsd)*t).long()
    return imsd[t].unique()
    
@patch
def hist_scaled(self:Tensor, brks=None):
    "Scales a tensor using `freqhist_bins` to values between 0 and 1"
    if self.device.type=='cuda': return self.hist_scaled_pt(brks)
    if brks is None: brks = self.freqhist_bins()
    ys = np.linspace(0., 1., len(brks))
    x = self.numpy().flatten()
    x = np.interp(x, brks.numpy(), ys)
    return tensor(x).reshape(self.shape).clamp(0.,1.)
    
    
@patch
def to_nchan(x:Tensor, wins, bins=None):
    res = [x.windowed(*win) for win in wins]
    if not isinstance(bins,int) or bins!=0: res.append(x.hist_scaled(bins).clamp(0,1))
    dim = [0,1][x.dim()==3]
    return TensorCTScan(torch.stack(res, dim=dim))

@patch
def save_jpg(x:(Tensor), path, wins, bins=None, quality=90):
    fn = Path(path).with_suffix('.jpg')
    x = (x.to_nchan(wins, bins)*255).byte()
    im = Image.fromarray(x.permute(1,2,0).numpy(), mode=['RGB','CMYK'][x.shape[0]==4])
    im.save(fn, quality=quality)

_,axs=subplots(1,1)

sample_slice.save_jpg('test.jpg', [dicom_windows.liver,dicom_windows.custom])
show_image(Image.open('test.jpg'), ax=axs[0])
# Out:
# <AxesSubplot: >

# %%
# Make custom JPG files for Unet training
# Total number of 131 nii files contains 67072 slices 

GENERATE_JPG_FILES = True   # warning: generation takes ~ 1h

if (GENERATE_JPG_FILES) :
    
    path = Path(".")

    os.makedirs('train_images',exist_ok=True)
    os.makedirs('train_masks',exist_ok=True)

    for ii in tqdm(range(0,len(df_files),3)): # take 1/3 nii files for training
        curr_ct        = read_nii(df_files.loc[ii,'dirname']+"/"+df_files.loc[ii,'filename'])
        curr_mask      = read_nii(df_files.loc[ii,'mask_dirname']+"/"+df_files.loc[ii,'mask_filename'])
        curr_file_name = str(df_files.loc[ii,'filename']).split('.')[0]
        curr_dim       = curr_ct.shape[2] # 512, 512, curr_dim

        for curr_slice in range(0,curr_dim,2): # export every 2nd slice for training
            data = tensor(curr_ct[...,curr_slice].astype(np.float32))
            mask = Image.fromarray(curr_mask[...,curr_slice].astype('uint8'), mode="L")
            data.save_jpg(f"train_images/{curr_file_name}_slice_{curr_slice}.jpg", [dicom_windows.liver,dicom_windows.custom])
            mask.save(f"train_masks/{curr_file_name}_slice_{curr_slice}_mask.png")
else:
    
    path = Path("../input/liver-segmentation-with-fastai-v2") # read jpg from saved kernel output
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %% [markdown]
# Model Training

# %%
bs = 16
im_size = 128

codes = np.array(["background","liver","tumor"])
    
def get_x(fname:Path): return fname
def label_func(x): return path/'train_masks'/f'{x.stem}_mask.png'

tfms = [IntToFloatTensor(),Normalize()]

db = DataBlock(blocks=(ImageBlock(),MaskBlock(codes)),  #codes = {"Backround": 0,"Liver": 1,"Tumor": 2}
               batch_tfms=tfms,
               splitter=RandomSplitter(),
               item_tfms=[Resize(im_size)],
               get_items=get_image_files,
               get_y=label_func
              )

ds = db.datasets(source=path/'train_images')

# %%
idx=20
imgs = [ds[idx][0],ds[idx][1]]
fig,axs = plt.subplots(1, 2)
for i,ax in enumerate(axs.flatten()):
    ax.axis('off')
    ax.imshow(imgs[i]) #, cmap='gray'

# %%
unique, counts = np.unique(array(ds[idx][1]), return_counts=True)

print( np.array((unique, counts)).T)
# Out:
# [[     0 262144]]

# %%
dls = db.dataloaders(path/'train_images',bs = bs) #, num_workers=0
dls.show_batch()

# %%
def foreground_acc(inp, targ, bkg_idx=0, axis=1):  # exclude a background from metric
    "Computes non-background accuracy for multiclass segmentation"
    targ = targ.squeeze(1)
    mask = targ != bkg_idx
    return (inp.argmax(dim=axis)[mask]==targ[mask]).float().mean() 

def cust_foreground_acc(inp, targ):  # # include a background into the metric
    return foreground_acc(inp=inp, targ=targ, bkg_idx=3, axis=1) # 3 is a dummy value to include the background which is 0

# %%
learn = unet_learner(dls, resnet34, loss_func=CrossEntropyLossFlat(axis=1), metrics=[foreground_acc, cust_foreground_acc])
# Out:
# c:\Users\surya\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# c:\Users\surya\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
learn.lr_find()
# Out:
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
#
#
#     <div>
#       <progress value='0' class='' max='118' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/118 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14804\2434377672.py in <module>
# ----> 1 learn.lr_find()
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\callback\schedule.py in lr_find(self, start_lr, end_lr, num_it, stop_div, show_plot, suggest_funcs)
#     291     n_epoch = num_it//len(self.dls.train) + 1
#     292     cb=LRFinder(start_lr=start_lr, end_lr=end_lr, num_it=num_it, stop_div=stop_div)
# --> 293     with self.no_logging(): self.fit(n_epoch, cbs=cb)
#     294     if suggest_funcs is not None:
#     295         lrs, losses = tensor(self.recorder.lrs[num_it//10:-5]), tensor(self.recorder.losses[num_it//10:-5])
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     262             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     263             self.n_epoch = n_epoch
# --> 264             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     265
#     266     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     197
#     198     def _with_events(self, f, event_type, ex, final=noop):
# --> 199         try: self(f'before_{event_type}');  f()
#     200         except ex: self(f'after_cancel_{event_type}')
#     201         self(f'after_{event_type}');  final()
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _do_fit(self)
#     251         for epoch in range(self.n_epoch):
#     252             self.epoch=epoch
# --> 253             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     254
#     255     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False, start_epoch=0):
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     197
#     198     def _with_events(self, f, event_type, ex, final=noop):
# --> 199         try: self(f'before_{event_type}');  f()
#     200         except ex: self(f'after_cancel_{event_type}')
#     201         self(f'after_{event_type}');  final()
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _do_epoch(self)
#     245
#     246     def _do_epoch(self):
# --> 247         self._do_epoch_train()
#     248         self._do_epoch_validate()
#     249
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _do_epoch_train(self)
#     237     def _do_epoch_train(self):
#     238         self.dl = self.dls.train
# --> 239         self._with_events(self.all_batches, 'train', CancelTrainException)
#     240
#     241     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     197
#     198     def _with_events(self, f, event_type, ex, final=noop):
# --> 199         try: self(f'before_{event_type}');  f()
#     200         except ex: self(f'after_cancel_{event_type}')
#     201         self(f'after_{event_type}');  final()
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in all_batches(self)
#     203     def all_batches(self):
#     204         self.n_iter = len(self.dl)
# --> 205         for o in enumerate(self.dl): self.one_batch(*o)
#     206
#     207     def _backward(self): self.loss_grad.backward()
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in one_batch(self, i, b)
#     233         b = self._set_device(b)
#     234         self._split(b)
# --> 235         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     236
#     237     def _do_epoch_train(self):
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     197
#     198     def _with_events(self, f, event_type, ex, final=noop):
# --> 199         try: self(f'before_{event_type}');  f()
#     200         except ex: self(f'after_cancel_{event_type}')
#     201         self(f'after_{event_type}');  final()
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _do_one_batch(self)
#     221         self('after_loss')
#     222         if not self.training or not len(self.yb): return
# --> 223         self._do_grad_opt()
#     224
#     225     def _set_device(self, b):
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _do_grad_opt(self)
#     209
#     210     def _do_grad_opt(self):
# --> 211         self._with_events(self._backward, 'backward', CancelBackwardException)
#     212         self._with_events(self._step, 'step', CancelStepException)
#     213         self.opt.zero_grad()
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     197
#     198     def _with_events(self, f, event_type, ex, final=noop):
# --> 199         try: self(f'before_{event_type}');  f()
#     200         except ex: self(f'after_cancel_{event_type}')
#     201         self(f'after_{event_type}');  final()
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\learner.py in _backward(self)
#     205         for o in enumerate(self.dl): self.one_batch(*o)
#     206
# --> 207     def _backward(self): self.loss_grad.backward()
#     208     def _step(self): self.opt.step()
#     209
#
# c:\Users\surya\anaconda3\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     477         """
#     478         if has_torch_function_unary(self):
# --> 479             return handle_torch_function(
#     480                 Tensor.backward,
#     481                 (self,),
#
# c:\Users\surya\anaconda3\lib\site-packages\torch\overrides.py in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1532         # Use `public_api` instead of `implementation` so __torch_function__
#    1533         # implementations can do equality/identity comparisons.
# -> 1534         result = torch_func_method(public_api, types, args, kwargs)
#    1535
#    1536         if result is not NotImplemented:
#
# c:\Users\surya\anaconda3\lib\site-packages\fastai\torch_core.py in __torch_function__(cls, func, types, args, kwargs)
#     370         if cls.debug and func.__name__ not in ('__str__','__repr__'): print(func, types, args, kwargs)
#     371         if _torch_handled(args, cls._opt, func): types = (torch.Tensor,)
# --> 372         res = super().__torch_function__(func, types, args, ifnone(kwargs, {}))
#     373         dict_objs = _find_args(args) if args else _find_args(list(kwargs.values()))
#     374         if issubclass(type(res),TensorBase) and dict_objs: res.set_meta(dict_objs[0],as_copy=True)
#
# c:\Users\surya\anaconda3\lib\site-packages\torch\_tensor.py in __torch_function__(cls, func, types, args, kwargs)
#    1277
#    1278         with _C.DisableTorchFunction():
# -> 1279             ret = func(*args, **kwargs)
#    1280             if func in get_default_nowrap_functions():
#    1281                 return ret
#
# c:\Users\surya\anaconda3\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     486                 inputs=inputs,
#     487             )
# --> 488         torch.autograd.backward(
#     489             self, gradient, retain_graph, create_graph, inputs=inputs
#     490         )
#
# c:\Users\surya\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
learn.fine_tune(5, wd=0.1, cbs=SaveModelCallback() )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>cust_foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.007510</td>
#       <td>0.005238</td>
#       <td>0.932791</td>
#       <td>0.998050</td>
#       <td>36:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.005522</td>
#       <td>0.003686</td>
#       <td>0.951228</td>
#       <td>0.998598</td>
#       <td>26:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.003789</td>
#       <td>0.003233</td>
#       <td>0.973700</td>
#       <td>0.998783</td>
#       <td>27:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.002931</td>
#       <td>0.002552</td>
#       <td>0.966471</td>
#       <td>0.998986</td>
#       <td>32:36</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.002467</td>
#       <td>0.002426</td>
#       <td>0.971693</td>
#       <td>0.999049</td>
#       <td>39:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()

# %%
# Save the model
learn.export(path/f'Liver_segmentation')

# %% [markdown]
# Test

# %%
# Load saved model
if (GENERATE_JPG_FILES) :
    
    tfms = [Resize(im_size), IntToFloatTensor(),Normalize()]
    learn0               = load_learner(path/f'Liver_segmentation',cpu=False )
    learn0.dls.transform = tfms

# %%
def nii_tfm(fn,wins): 

    test_nii  = read_nii(fn)
    curr_dim  = test_nii.shape[2] # 512, 512, curr_dim
    slices = []
    
    for curr_slice in range(curr_dim):
        data = tensor(test_nii[...,curr_slice].astype(np.float32))
        data = (data.to_nchan(wins)*255).byte()
        slices.append(TensorImage(data))
                      
    return slices

# %%
tst = 20

test_nii   = read_nii(df_files.loc[tst,'dirname']+"/"+df_files.loc[tst,'filename'])
test_mask  = read_nii(df_files.loc[tst,'mask_dirname']+"/"+df_files.loc[tst,'mask_filename'])
print(test_nii.shape)

test_slice_idx = 500

sample_slice = tensor(test_nii[...,test_slice_idx].astype(np.float32))

plot_sample([test_nii[...,test_slice_idx], test_mask[...,test_slice_idx]])
# Out:
# (512, 512, 861)

# %%
# Prepare a nii test file for prediction 

test_files = nii_tfm(df_files.loc[tst,'dirname']+"/"+df_files.loc[tst,'filename'],[dicom_windows.liver, dicom_windows.custom])
print("Number of test slices: ",len(test_files))
# Out:
# Number of test slices:  861

# %%
# Check an input for a test file
show_image(test_files[test_slice_idx])
# Out:
# <AxesSubplot: >

# %%
# Get predictions for a Test file

test_dl = learn0.dls.test_dl(test_files)
preds, y = learn0.get_preds(dl=test_dl)

predicted_mask = np.argmax(preds, axis=1)
plt.imshow(predicted_mask[test_slice_idx])

# %%
a=np.array(predicted_mask[test_slice_idx])
np.amin(a),np.amax(a),
# Out:
# (0, 2)
